# %% [markdown]
# # No Man's Sky.
# Natural language processing.

# %% [markdown]
# ### Foreword
# Given the massive number of reviews for the game, is there a way to generate unique summaries in relative to certain conditions? Of course, and that's where the concept of <b>natural language processing</b> comes in.
#
# The reviews are going to be divided into <b>years</b> and rather they are <b>positive</b> or <b>negative</b>, and there will be a dataframe built upon the many different summaries generated.

# %%
import pandas as pd
from datetime import datetime

import math

import nltk
from nltk.corpus import stopwords
from nltk.cluster.util import cosine_distance
import numpy as np
import networkx as nx

# %%
df = pd.read_json("./mns-data/nms_data.json")

# %%
maindata = df[:121916]
metadata = df[121916:]

# %%
id_data = [maindata['reviews'][i]['recommendationid'] for i in range(len(maindata))]
mnsdata = pd.DataFrame(id_data, columns = ['id'])
mnsdata
# Out:
#               id
# 0       92447055
# 1       92446235
# 2       92445739
# 3       92445679
# 4       92445399
# ...          ...
# 121911  24845464
# 121912  24845460
# 121913  24845437
# 121914  24845428
# 121915  24845425
#
# [121916 rows x 1 columns]

# %%
reviews_data = [maindata['reviews'][i]['review'] for i in range(len(maindata))]
review_votes = [maindata['reviews'][i]['voted_up'] for i in range(len(maindata))]

mnsdata['Reviews'] = reviews_data
mnsdata['Recommended?'] = review_votes

mnsdata
# Out:
#               id                                            Reviews  \
# 0       92447055                  this is a game on the steam store
# 1       92446235              Space is great fun yes is great fun\n
# 2       92445739  Played half of my time on launch day in 2016 a...
# 3       92445679  Pretty impressive that they went out and made ...
# 4       92445399  Very fun open world game, however the multipla...
# ...          ...                                                ...
# 121911  24845464                              Quite nice, actually.
# 121912  24845460  Rest in peace Harambe. Your name will always b...
# 121913  24845437  1ST PUBLIC REVIEW!\n\nEDIT: Quick tips, left c...
# 121914  24845428  Its pretty good tbh\nEDIT: Its pretty good but...
# 121915  24845425  yeah m8, this is gr8, no d-b8 i r8 it an 8 i h...
#
#         Recommended?
# 0              False
# 1               True
# 2               True
# 3               True
# 4               True
# ...              ...
# 121911          True
# 121912          True
# 121913          True
# 121914         False
# 121915          True
#
# [121916 rows x 3 columns]

# %%
timestamp = [maindata['reviews'][i]['timestamp_updated'] for i in range(len(maindata))]
date = [datetime.fromtimestamp(timestamp[i]).strftime('%Y-%m-%d') for i in range(len(timestamp))]

mnsdata['Date'] = date
mnsdata['Yearly'] = mnsdata['Date'].str[0:4]
mnsdata['Monthly'] = mnsdata['Date'].str[0:4]+mnsdata['Date'].str[5:7]

mnsdata
# Out:
#               id                                            Reviews  \
# 0       92447055                  this is a game on the steam store
# 1       92446235              Space is great fun yes is great fun\n
# 2       92445739  Played half of my time on launch day in 2016 a...
# 3       92445679  Pretty impressive that they went out and made ...
# 4       92445399  Very fun open world game, however the multipla...
# ...          ...                                                ...
# 121911  24845464                              Quite nice, actually.
# 121912  24845460  Rest in peace Harambe. Your name will always b...
# 121913  24845437  1ST PUBLIC REVIEW!\n\nEDIT: Quick tips, left c...
# 121914  24845428  Its pretty good tbh\nEDIT: Its pretty good but...
# 121915  24845425  yeah m8, this is gr8, no d-b8 i r8 it an 8 i h...
#
#         Recommended?        Date Yearly Monthly
# 0              False  2021-05-22   2021  202105
# 1               True  2021-05-22   2021  202105
# 2               True  2021-05-22   2021  202105
# 3               True  2021-05-22   2021  202105
# 4               True  2021-05-22   2021  202105
# ...              ...         ...    ...     ...
# 121911          True  2016-08-13   2016  201608
# 121912          True  2018-07-25   2018  201807
# 121913          True  2016-08-12   2016  201608
# 121914         False  2016-08-17   2016  201608
# 121915          True  2016-08-12   2016  201608
#
# [121916 rows x 6 columns]

# %% [markdown]
# This is very much built like the analytics side of things but with much fewer columns. We only need <b>Reviews</b>, <b>Recommended?</b>, <b>Date</b>, <b>Yearly</b>, and <b>Monthly</b>. Everything else is background noise.

# %% [markdown]
# ### Natural language processing

# %%
def sentence_similarity(sent1, sent2, stopwords=None):
    if stopwords is None:
        stopwords = []
    sent1 = [w.lower() for w in sent1]
    sent2 = [w.lower() for w in sent2]
    all_words = list(set(sent1+sent2))
    
    vector1 = [0] * len(all_words)
    vector2 = [0] * len(all_words)
    
    for w in sent1:
        if w in stopwords:
            continue
        vector1[all_words.index(w)] += 1
        
    for w in sent2:
        if w in stopwords:
            continue
        vector2[all_words.index(w)] += 1
        
    return 1-cosine_distance(vector1, vector2)

def gen_sim_matrix(sentences, stop_words):
    similarity_matrix = np.zeros((len(sentences), len(sentences)))
    for idx1 in range(len(sentences)):
        for idx2 in range(len(sentences)):
            if idx1 == idx2:
                continue
            similarity_matrix[idx1][idx2] = sentence_similarity(sentences[idx1], sentences[idx2], stop_words)
            
    return similarity_matrix

def generate_summary(reviews, top_n=5):
    stop_words = stopwords.words('english')
    summarize_text = []
    sentence_similarity_matrix = gen_sim_matrix(reviews, stop_words)
    sentence_similarity_graph = nx.from_numpy_array(sentence_similarity_matrix)
    scores = nx.pagerank(sentence_similarity_graph)
    ranked_sentence = sorted(((scores[i], s) for i, s in enumerate(reviews)), reverse=True)

    for i in range(top_n):
        summarize_text.append("".join(ranked_sentence[i][1]))
        
    return summarize_text

# %% [markdown]
# Code provided from here: https://www.youtube.com/watch?v=dFe7tbH39Eg

# %% [markdown]
# ### Summerisation

# %% [markdown]
# #### NLP 2016 positives

# %%
mns_2016_positive = []

for i in range(len(mnsdata.loc[(mnsdata['Yearly'] == '2016') & (mnsdata['Recommended?'] == True)])):
    if 10 <= len(mnsdata.loc[(mnsdata['Yearly'] == '2016') & (mnsdata['Recommended?'] == True)]['Reviews'].values[i]) <= 30:
        mns_2016_positive.append(mnsdata.loc[(mnsdata['Yearly'] == '2016') & (mnsdata['Recommended?'] == True)]['Reviews'].values[i])

# %%
nlp_initial_2016_positive = [mns_2016_positive[(i*50):(i+1)*50] for i in range(math.ceil(len(mns_2016_positive)/50))]
nlp_aggregate_2016_positive = []

for i in range(len(nlp_initial_2016_positive)):
    try:
        nlp_aggregate_2016_positive += generate_summary(nlp_initial_2016_positive[i])
    except:
        continue
# Out:
# c:\users\ken\appdata\local\programs\python\python38-32\lib\site-packages\nltk\cluster\util.py:131: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (numpy.dot(u, v) / (sqrt(numpy.dot(u, u)) * sqrt(numpy.dot(v, v))))

# %%
nlp_aggregate_2016_positive.pop(19)
nlp_aggregate_2016_positive
# Out:
# ['New update is looking great.',
#  'New update is pretty good',
#  'the game is pritty good now',
#  "It's a decent game.",
#  'It might get better.',
#  'New update is great.',
#  'i just wanted to be different',
#  'Best Money Disposal Simulator',
#  'I just want to be different.',
#  'It is a nice game.',
#  'I strangely like this game.',
#  'best game ive played in years.',
#  'I really enjoy this game',
#  'I LOVE THIS GAME',
#  'pretty good i guess',
#  'well its fine i guess',
#  'I liked the hype I guess.',
#  'get it son',
#  "It's all about the adventure.",
#  'Very good and beatiful game',
#  "I like it, even can't stop.",
#  'The most amazing game ever !!',
#  "I've really enjoyed this game.",
#  'Love it, Dont care.',
#  'i love this game',
#  'EPIC game for us explorers ;)',
#  'I represent the sub reddit ;)',
#  'Fun exploration game',
#  'The Perfect Stoner Game',
#  "I's a great game I love it.",
#  'I like being lied to!',
#  'Cool game - great time killer',
#  'so far its a great game',
#  'I really like this game',
#  'Loving the game so far!',
#  'At least I got a refund',
#  "it's a verry nice game!",
#  "It's a great game, mate.",
#  'Not working great game! :D',
#  'Very fun game lots to do.',
#  'A great game of exploration!',
#  'good  but it need some repeirs',
#  'Worked for me and I enjoy it.',
#  'How do i get antimatter?',
#  'Loving every moment of this.',
#  'Good fun exploration game.',
#  "If it runs it's great.",
#  'Awesome game loads of fun',
#  'Not bad, needs more planets.',
#  'This game, is now my life.',
#  'If the game works then yay',
#  'Really enjoying it so far.',
#  "My game won't initialise, man.",
#  'Just what I needed. Thanks.',
#  'I really enjoy that game.',
#  'really liking this game so far',
#  'great game, can easily play',
#  'i love the game soo far',
#  'nice game I have no issues',
#  'game runs perfect love it!',
#  'like elite dangerous but good',
#  'The refund button works well.',
#  'Great game :) love it',
#  'In Love with this game']

# %%
nlp_aggregate_2016_positive.pop(35)
nlp_aggregate_2016_positive
# Out:
# ['New update is looking great.',
#  'New update is pretty good',
#  'the game is pritty good now',
#  "It's a decent game.",
#  'It might get better.',
#  'New update is great.',
#  'i just wanted to be different',
#  'Best Money Disposal Simulator',
#  'I just want to be different.',
#  'It is a nice game.',
#  'I strangely like this game.',
#  'best game ive played in years.',
#  'I really enjoy this game',
#  'I LOVE THIS GAME',
#  'pretty good i guess',
#  'well its fine i guess',
#  'I liked the hype I guess.',
#  'get it son',
#  "It's all about the adventure.",
#  'Very good and beatiful game',
#  "I like it, even can't stop.",
#  'The most amazing game ever !!',
#  "I've really enjoyed this game.",
#  'Love it, Dont care.',
#  'i love this game',
#  'EPIC game for us explorers ;)',
#  'I represent the sub reddit ;)',
#  'Fun exploration game',
#  'The Perfect Stoner Game',
#  "I's a great game I love it.",
#  'I like being lied to!',
#  'Cool game - great time killer',
#  'so far its a great game',
#  'I really like this game',
#  'Loving the game so far!',
#  "it's a verry nice game!",
#  "It's a great game, mate.",
#  'Not working great game! :D',
#  'Very fun game lots to do.',
#  'A great game of exploration!',
#  'good  but it need some repeirs',
#  'Worked for me and I enjoy it.',
#  'How do i get antimatter?',
#  'Loving every moment of this.',
#  'Good fun exploration game.',
#  "If it runs it's great.",
#  'Awesome game loads of fun',
#  'Not bad, needs more planets.',
#  'This game, is now my life.',
#  'If the game works then yay',
#  'Really enjoying it so far.',
#  "My game won't initialise, man.",
#  'Just what I needed. Thanks.',
#  'I really enjoy that game.',
#  'really liking this game so far',
#  'great game, can easily play',
#  'i love the game soo far',
#  'nice game I have no issues',
#  'game runs perfect love it!',
#  'like elite dangerous but good',
#  'The refund button works well.',
#  'Great game :) love it',
#  'In Love with this game']

# %%
nlp_aggregate_2016_positive.pop(51)
nlp_aggregate_2016_positive
# Out:
# ['New update is looking great.',
#  'New update is pretty good',
#  'the game is pritty good now',
#  "It's a decent game.",
#  'It might get better.',
#  'New update is great.',
#  'i just wanted to be different',
#  'Best Money Disposal Simulator',
#  'I just want to be different.',
#  'It is a nice game.',
#  'I strangely like this game.',
#  'best game ive played in years.',
#  'I really enjoy this game',
#  'I LOVE THIS GAME',
#  'pretty good i guess',
#  'well its fine i guess',
#  'I liked the hype I guess.',
#  'get it son',
#  "It's all about the adventure.",
#  'Very good and beatiful game',
#  "I like it, even can't stop.",
#  'The most amazing game ever !!',
#  "I've really enjoyed this game.",
#  'Love it, Dont care.',
#  'i love this game',
#  'EPIC game for us explorers ;)',
#  'I represent the sub reddit ;)',
#  'Fun exploration game',
#  'The Perfect Stoner Game',
#  "I's a great game I love it.",
#  'I like being lied to!',
#  'Cool game - great time killer',
#  'so far its a great game',
#  'I really like this game',
#  'Loving the game so far!',
#  "it's a verry nice game!",
#  "It's a great game, mate.",
#  'Not working great game! :D',
#  'Very fun game lots to do.',
#  'A great game of exploration!',
#  'good  but it need some repeirs',
#  'Worked for me and I enjoy it.',
#  'How do i get antimatter?',
#  'Loving every moment of this.',
#  'Good fun exploration game.',
#  "If it runs it's great.",
#  'Awesome game loads of fun',
#  'Not bad, needs more planets.',
#  'This game, is now my life.',
#  'If the game works then yay',
#  'Really enjoying it so far.',
#  'Just what I needed. Thanks.',
#  'I really enjoy that game.',
#  'really liking this game so far',
#  'great game, can easily play',
#  'i love the game soo far',
#  'nice game I have no issues',
#  'game runs perfect love it!',
#  'like elite dangerous but good',
#  'The refund button works well.',
#  'Great game :) love it',
#  'In Love with this game']

# %%
nlp_aggregate_2016_positive.pop(59)
nlp_aggregate_2016_positive
# Out:
# ['New update is looking great.',
#  'New update is pretty good',
#  'the game is pritty good now',
#  "It's a decent game.",
#  'It might get better.',
#  'New update is great.',
#  'i just wanted to be different',
#  'Best Money Disposal Simulator',
#  'I just want to be different.',
#  'It is a nice game.',
#  'I strangely like this game.',
#  'best game ive played in years.',
#  'I really enjoy this game',
#  'I LOVE THIS GAME',
#  'pretty good i guess',
#  'well its fine i guess',
#  'I liked the hype I guess.',
#  'get it son',
#  "It's all about the adventure.",
#  'Very good and beatiful game',
#  "I like it, even can't stop.",
#  'The most amazing game ever !!',
#  "I've really enjoyed this game.",
#  'Love it, Dont care.',
#  'i love this game',
#  'EPIC game for us explorers ;)',
#  'I represent the sub reddit ;)',
#  'Fun exploration game',
#  'The Perfect Stoner Game',
#  "I's a great game I love it.",
#  'I like being lied to!',
#  'Cool game - great time killer',
#  'so far its a great game',
#  'I really like this game',
#  'Loving the game so far!',
#  "it's a verry nice game!",
#  "It's a great game, mate.",
#  'Not working great game! :D',
#  'Very fun game lots to do.',
#  'A great game of exploration!',
#  'good  but it need some repeirs',
#  'Worked for me and I enjoy it.',
#  'How do i get antimatter?',
#  'Loving every moment of this.',
#  'Good fun exploration game.',
#  "If it runs it's great.",
#  'Awesome game loads of fun',
#  'Not bad, needs more planets.',
#  'This game, is now my life.',
#  'If the game works then yay',
#  'Really enjoying it so far.',
#  'Just what I needed. Thanks.',
#  'I really enjoy that game.',
#  'really liking this game so far',
#  'great game, can easily play',
#  'i love the game soo far',
#  'nice game I have no issues',
#  'game runs perfect love it!',
#  'like elite dangerous but good',
#  'Great game :) love it',
#  'In Love with this game']

# %%
nlp_2016_positive = generate_summary(nlp_aggregate_2016_positive)
nlp_2016_positive
# Out:
# ['best game ive played in years.',
#  'i love the game soo far',
#  'good  but it need some repeirs',
#  'Very good and beatiful game',
#  'Very fun game lots to do.']

# %% [markdown]
# #### NLP 2016 negatives

# %%
mns_2016_negative = []

for i in range(len(mnsdata.loc[(mnsdata['Yearly'] == '2016') & (mnsdata['Recommended?'] == False)])):
    if 10 <= len(mnsdata.loc[(mnsdata['Yearly'] == '2016') & (mnsdata['Recommended?'] == False)]['Reviews'].values[i]) <= 30:
        mns_2016_negative.append(mnsdata.loc[(mnsdata['Yearly'] == '2016') & (mnsdata['Recommended?'] == False)]['Reviews'].values[i])

# %%
nlp_initial_2016_negative = [mns_2016_negative[(i*50):(i+1)*50] for i in range(math.ceil(len(mns_2016_negative)/50))]
nlp_aggregate_2016_negative = []

for i in range(len(nlp_initial_2016_negative)):
    try:
        nlp_aggregate_2016_negative += generate_summary(nlp_initial_2016_negative[i])
    except:
        continue

# %%
nlp_aggregate_2016_negative
# Out:
# ['Just dont buy this trash game.',
#  'A total waste of time.',
#  '4 thumbs down for the dev',
#  'it act like a penis',
#  'Dont. Not even if its on sale.',
#  'Better than playing with Pedro',
#  'DO NOT BUY THIS GAME.',
#  'Waste of time and money',
#  'lets see this new update',
#  'This game is really bad',
#  'legit could not be worse',
#  'Would be a great 5$ game',
#  'this game sucks big time.',
#  "Just don't. (Even in sales)",
#  'No enough to do',
#  'I tried to ignore the lies',
#  'Worst game ever.  That is all.',
#  'This game was a let down.',
#  'this game sux donkey ballz.',
#  'Writing this review at 98 days',
#  'Not worth the time or money.',
#  'pile of steaming horse shit',
#  "It's tech demo, nothing more.",
#  'Wtf even is this garbage.',
#  'No Mans Sky = One Big Lie.. \n\n',
#  "Seriously don't get it",
#  'Giant lie, do not buy.',
#  "Don't waste your time or cash.",
#  "Just don't even try this game",
#  "Waste of time. Don't buy.",
#  'i forgot i owned this game',
#  'DONT EVER BUY THIS GAME AT 70$',
#  'isnt like how they said it',
#  'DO NOT BUY THIS GAME.',
#  'Repetitive and boring as shit.',
#  'WHY  WONT IT LET ME REFUND.',
#  'too late to get a refund :(',
#  'Ok. No real game here.',
#  'You will never like this game!',
#  'Not worth the money at all',
#  'can i still get a refund',
#  'Can i still get my refund?',
#  'Wish I had gotten my refund',
#  'THE GAME IS A LIE',
#  'Sean Murray can suck a chode',
#  'give me my refund dammit',
#  'My worst buy in steam so far.',
#  'no good, just waste of money',
#  'i waited for a year, kill me',
#  'cancer in an open world game',
#  "I can't even play this game.",
#  'DONT BUY THE GAME',
#  'Not the game i anticipated',
#  'so i really want my money back',
#  'Burn in hell Sean Murray.',
#  'Sean Murray can go to hell.',
#  'can i get a refund?',
#  'I did not enjoy this game.',
#  'Sean is a liar\n',
#  "DON'T BUY IT \nNO MANS LIE",
#  'Everyone should get a refund.',
#  'empty. all you need to know',
#  'best mini-game worst full game',
#  "don't waste your time",
#  'Really want a refund.',
#  'So much wasted potential.',
#  'what a broken pile of shit',
#  'sean murray can fucking do one',
#  '"A mile wide and an inch deep"',
#  'long story short they lied.',
#  'I should get a refund.',
#  'Is there anything more to say?',
#  "Just don't bother.",
#  'Uh-oh, I made the bad game. :(',
#  'Made by a liar.',
#  'Sean Murray is God obviously',
#  "Money Grab.  Don't buy!",
#  ' I WANT A REFUND!',
#  'The game is a huge let down',
#  "Didn't get a refund",
#  'Worst lie ever DO NOT BUY',
#  'Game is not as advertised.',
#  'Horrible scam, dont buy it.',
#  'Can I have my refund now?',
#  "Falsely advertized, don't buy.",
#  'I DEMAND A REFUND N THIS GAME.',
#  'Please do NOT buy this game!',
#  'Well the refund button works.',
#  'No. I got a refund.',
#  "No Man's Junk is more like it.",
#  'When do i get the refund?',
#  'does not work for intel',
#  'Seaun wont let me refund :^',
#  'I gave it a chance. No bueno.',
#  'do not buy waste of money',
#  "Don't waste your money.",
#  'Not what it clained to be.',
#  "Don't waste your time.",
#  'So many lies. Do not buy.',
#  'Valve denide me a refund.',
#  'i wish i could get refund',
#  'Seriously not good. Do not buy',
#  "Still can't get a refund.",
#  'Do not buy this game.',
#  'One Guys Lie\nNo Mans Buy',
#  'Hate It SOOOOOOO boring',
#  'Pretty cool, but its boring.',
#  "Didn't live up to the hype.",
#  'Do not buy. This game is shit.',
#  "Fuck this I'm getting bad rats",
#  'NEVER PLAY THIS GAME RIP OFF',
#  'The game of broken promises',
#  'How do i get a refund?',
#  'way to expensive for this crap',
#  'In one word SPORE sequel',
#  'a refund would be nice thanks',
#  "Mods can't even fix this game.",
#  'Do NOT buy this lie',
#  'Thank god i got my refund.',
#  'What a waste of money and time',
#  'Thanks for the refund Gaben.',
#  'Simply not worth the money.',
#  'DO NOT BUY THIS GAME.',
#  'Not worth $60 on my best day.',
#  'refund no longer works ):',
#  'I want to play the trailer.',
#  'This is a false advertising!',
#  'I actually hate Sean Murray',
#  'Not as fun as expected.',
#  'Bigger letdown than Obama.',
#  'i do not recomend this game',
#  "So boring I can't believe it.",
#  'more like no guy buy lmao',
#  'a game that simulates a game',
#  'Do not get',
#  'Would not recommend this game',
#  'Can I have a refund please?',
#  'I never did a review. Til now.',
#  'Like Spore, only more boring.',
#  'Did not deliver.',
#  'Not worth your time or money',
#  'What an incredible let down.',
#  'This game is very bad',
#  '"a mile wide and an inch deep"',
#  "Don't even consider buying it.",
#  'dont waste your time or money',
#  'False advertising at its best',
#  'Trust me, it WILL get boring.',
#  'Not getting what you paid for.',
#  'bad game waste of my money',
#  'Empty, it was a true let down.',
#  'Not worth the price. Big flop.',
#  "More like No Man's Lies.",
#  'this game was very poorly made',
#  'realy not worth the 60 bucks',
#  'Boring waste of time.',
#  ' Sold on false promises',
#  'Not worth the price tag.',
#  'Boring not fun and a total lie',
#  'Do not buy this game.',
#  'Awful game. not asadvertised.',
#  'bouring waste of time',
#  "Don't waste your time.",
#  'Another victim of the hype.',
#  "Don't buy this game, simple",
#  'Dont waste your time friend.',
#  'I wanted to like this.',
#  'Gets old after about 10 hrs.',
#  'Three things to do',
#  'Very stale after a few hours',
#  'A refund would be nice.',
#  'A mile wide and an inch deep.',
#  'Game would never start.',
#  'Gets boring after a few hours',
#  'Do not buy this game.',
#  'I fell to the hype train',
#  'Smiply Waste Of Time And Money',
#  'i wish i could refund it',
#  'Not worthy the price .',
#  'Game was not as advertised',
#  'Needs alot of work',
#  'Same shit different planet',
#  'One Mans Lie.',
#  'Too many lies',
#  'thank Gaben for refunds',
#  'can i plz get a refund',
#  'A mile wide but an inch deep',
#  'lo freame rate so lown it succ',
#  'So much promised, so many lies',
#  'I want a refund.',
#  'utter shit, nothing but lies.',
#  'I got scammed, No Multiplayer.',
#  'terrible game only worth 20',
#  "Worst Hype ever. Don't buy.",
#  'where is that refund button?',
#  'how NOT to optimize a game',
#  'When do I get my refund?',
#  'Spores is the true no man sky',
#  'A brand new $60 meme!',
#  'Not worth the money.',
#  'To bad the refunds stopped.',
#  'Meh. Not what was advertised.',
#  'Miles wide, one inch deep.',
#  'the refund button works well',
#  'This game is a chore.',
#  ' The game looks plain bad.',
#  'God is dead and we killed him.',
#  'I Want my money back... Period',
#  "It really is No Man's Sky.",
#  'Glad the return button worked',
#  'I spend 60 euros for nothing\n',
#  'It needs lots of work!',
#  'The snake is a lie.',
#  "tfw game doesn't even start.",
#  'I give it a torrent out of 10',
#  'the world is full of nothing',
#  "Won't run, got it refunded.",
#  'refund button works well.',
#  'can not get past intro',
#  'a refund well claimed.',
#  'get a refund while you can',
#  '>implying video games are fun',
#  'Long story short one mans lie',
#  'Where do I refund',
#  "Game don't even start.",
#  'Awful game, does not even run.',
#  'Not a very fun game.',
#  'crahes before i can get in',
#  'Game is currently broken',
#  'Refund all the way',
#  'I do not recommend this game',
#  'I like the refund button.',
#  'As the game is now no',
#  'Glitchy and does not run well',
#  'Do not buy this game',
#  'over hyped and boring.',
#  'Single player only, game sux',
#  'lol crashes on start',
#  'You need Opengl 4.5. Sigh',
#  'same ol same ol after a bit',
#  'Game would not start.',
#  'the game crashes on startup',
#  'not until they fix the game',
#  'NOT. EVEN. ONCE. (WILL IT RUN)',
#  'piece of shit game dont buy',
#  'More like Nope, Not A Buy',
#  'Straight to the refund bin!',
#  'REV UP THOSE REFUNDS LADS',
#  'dont waste your money on this',
#  "The refund button doesn't work",
#  'does not run well on my 970.',
#  'How do I get a refund?',
#  "Can't even start the game.",
#  'really bad waste of money',
#  'Did not enjoy this game.',
#  'Runs like a toaster PC game.',
#  'Game crashes on start up',
#  'Shooting rocks the game.',
#  'Intro, then crush. GG WP',
#  'Refunded.\n\nGame cant run well.',
#  'will not run from steam',
#  'At least spore fucking worked.',
#  'Stalls on the splash screen.',
#  'Unplayable on my computer.',
#  "More like No Man's Pie",
#  'Runs like a fat woman.',
#  'Big No No !  , runs like crap.',
#  'Thank God for Steam refunds',
#  'Fucking shit i want a refund',
#  'how do i get a refund\n',
#  'Crashing on the main screen',
#  'Well, this is refund...',
#  'Nice crash similator.',
#  'Game looks like dogasshole',
#  'oh the lies']

# %%
nlp_2016_negative = generate_summary(nlp_aggregate_2016_negative)
nlp_2016_negative
# Out:
# ['I DEMAND A REFUND N THIS GAME.',
#  'WHY  WONT IT LET ME REFUND.',
#  'get a refund while you can',
#  'Would not recommend this game',
#  'When do I get my refund?']

# %% [markdown]
# #### NLP 2017 positives

# %%
mns_2017_positive = []

for i in range(len(mnsdata.loc[(mnsdata['Yearly'] == '2017') & (mnsdata['Recommended?'] == True)])):
    if 10 <= len(mnsdata.loc[(mnsdata['Yearly'] == '2017') & (mnsdata['Recommended?'] == True)]['Reviews'].values[i]) <= 30:
        mns_2017_positive.append(mnsdata.loc[(mnsdata['Yearly'] == '2017') & (mnsdata['Recommended?'] == True)]['Reviews'].values[i])

# %%
nlp_initial_2017_positive = [mns_2017_positive[(i*50):(i+1)*50] for i in range(math.ceil(len(mns_2017_positive)/50))]
nlp_aggregate_2017_positive = []

for i in range(len(nlp_initial_2017_positive)):
    try:
        nlp_aggregate_2017_positive += generate_summary(nlp_initial_2017_positive[i])
    except:
        continue

# %%
nlp_aggregate_2017_positive
# Out:
# ['A nice game to get lost in.',
#  'me dude its great now',
#  'Better than a year ago.',
#  'nice game . come on',
#  'i cant even use it',
#  'Now the game looks great!',
#  'The game is super fun now.',
#  'Great game and nice view!',
#  "This game confirms I'm a nerd.",
#  'they kinda fixed it i guess',
#  'its getting alot better.',
#  'After update game is good',
#  'A true exploration game.',
#  'its like a proper game now',
#  'The game is getting better.',
#  'the cake is no longer a lie',
#  'New Update is really good',
#  "Way better than Old Man's Sky",
#  'much better now !',
#  'Would love to see this in VR',
#  'The 1.3 update is really nice.',
#  '1.3 is here, so get playing.',
#  'I think its pretty decent.',
#  'Just because I love this game.',
#  'Updates made it great.',
#  'hey man at least theyre trying',
#  'dis game is very seet',
#  "It's getting better !",
#  'Keep it up Hello Games',
#  'Hey, its pretty good!',
#  'This game got a lot better.',
#  'The game is now fixed.',
#  'Gettin better all the time.',
#  'Favorite game this year.',
#  "Started bad. Now it's good.",
#  'Turned out to be pretty good.',
#  'Had a great time.',
#  'its getting better, thats it',
#  'Its getting better now.',
#  'The new updates good',
#  'Game is enjoyable now.',
#  'its getting better',
#  'Free big updates \nnice',
#  'Its getting there',
#  'It got better.']

# %%
nlp_2017_positive = generate_summary(nlp_aggregate_2017_positive)
nlp_2017_positive
# Out:
# ['me dude its great now',
#  'Better than a year ago.',
#  'This game got a lot better.',
#  'hey man at least theyre trying',
#  'its getting better, thats it']

# %% [markdown]
# #### NLP 2017 negatives

# %%
mns_2017_negative = []

for i in range(len(mnsdata.loc[(mnsdata['Yearly'] == '2017') & (mnsdata['Recommended?'] == False)])):
    if 10 <= len(mnsdata.loc[(mnsdata['Yearly'] == '2017') & (mnsdata['Recommended?'] == False)]['Reviews'].values[i]) <= 30:
        mns_2017_negative.append(mnsdata.loc[(mnsdata['Yearly'] == '2017') & (mnsdata['Recommended?'] == False)]['Reviews'].values[i])

# %%
nlp_initial_2017_negative = [mns_2017_negative[(i*50):(i+1)*50] for i in range(math.ceil(len(mns_2017_negative)/50))]
nlp_aggregate_2017_negative = []

for i in range(len(nlp_initial_2017_negative)):
    try:
        nlp_aggregate_2017_negative += generate_summary(nlp_initial_2017_negative[i])
    except:
        continue

# %%
nlp_aggregate_2017_negative.pop(8)
nlp_aggregate_2017_negative
# Out:
# ['I tried to like this game.',
#  'Wish i could get a refund',
#  'Shit. Wasted alot of money',
#  'The lag is immersive.',
#  'Best game of all time.',
#  'Bigger let down than religion.',
#  'A ploy for money.',
#  'Please do not buy this!',
#  "No Man's Scam, trash game",
#  'how do i get a refund',
#  "Why didn't I request a refund",
#  'Not what has been promised',
#  'Bad game retarded dont buy.',
#  'Worst game that I ever played',
#  'Lies and promised too much',
#  'Too much hype for a trash game',
#  'how do i refund this',
#  'lyin sons of a bitches',
#  'worst game of the year',
#  'Do not buy. At least for now',
#  'F this company and game.',
#  "I got my refund so I'm happy",
#  'Still stinks after new updates',
#  'yep. its a big disapointment',
#  'This game cured my insomnia.',
#  'Kill me for buying htis game',
#  'trash dont ever get this game',
#  'DO NOT GET IT',
#  'Not worth my money',
#  'Get it on sale.',
#  'Thankfully I got a refund.',
#  'greatest scam in steam history',
#  'Still a huge disappointment',
#  'why the game cant run',
#  'GIVE US OUR MONEY BACK',
#  "No Man's PC can handle it.",
#  'i... just cant even',
#  'Its so fucking shit',
#  'Fucken blows\n']

# %%
nlp_aggregate_2017_negative.pop(24)
nlp_aggregate_2017_negative
# Out:
# ['I tried to like this game.',
#  'Wish i could get a refund',
#  'Shit. Wasted alot of money',
#  'The lag is immersive.',
#  'Best game of all time.',
#  'Bigger let down than religion.',
#  'A ploy for money.',
#  'Please do not buy this!',
#  "No Man's Scam, trash game",
#  'how do i get a refund',
#  "Why didn't I request a refund",
#  'Not what has been promised',
#  'Bad game retarded dont buy.',
#  'Worst game that I ever played',
#  'Lies and promised too much',
#  'Too much hype for a trash game',
#  'how do i refund this',
#  'lyin sons of a bitches',
#  'worst game of the year',
#  'Do not buy. At least for now',
#  'F this company and game.',
#  "I got my refund so I'm happy",
#  'Still stinks after new updates',
#  'yep. its a big disapointment',
#  'Kill me for buying htis game',
#  'trash dont ever get this game',
#  'DO NOT GET IT',
#  'Not worth my money',
#  'Get it on sale.',
#  'Thankfully I got a refund.',
#  'greatest scam in steam history',
#  'Still a huge disappointment',
#  'why the game cant run',
#  'GIVE US OUR MONEY BACK',
#  "No Man's PC can handle it.",
#  'i... just cant even',
#  'Its so fucking shit',
#  'Fucken blows\n']

# %%
nlp_2017_negative = generate_summary(nlp_aggregate_2017_negative)
nlp_2017_negative
# Out:
# ['how do i get a refund',
#  'Wish i could get a refund',
#  'Lies and promised too much',
#  'why the game cant run',
#  'Shit. Wasted alot of money']

# %% [markdown]
# #### NLP 2018 positive

# %%
mns_2018_positive = []

for i in range(len(mnsdata.loc[(mnsdata['Yearly'] == '2018') & (mnsdata['Recommended?'] == True)])):
    if 10 <= len(mnsdata.loc[(mnsdata['Yearly'] == '2018') & (mnsdata['Recommended?'] == True)]['Reviews'].values[i]) <= 30:
        mns_2018_positive.append(mnsdata.loc[(mnsdata['Yearly'] == '2018') & (mnsdata['Recommended?'] == True)]['Reviews'].values[i])

# %%
nlp_initial_2018_positive = [mns_2018_positive[(i*50):(i+1)*50] for i in range(math.ceil(len(mns_2018_positive)/50))]
nlp_aggregate_2018_positive = []

for i in range(len(nlp_initial_2018_positive)):
    try:
        nlp_aggregate_2018_positive += generate_summary(nlp_initial_2018_positive[i])
    except:
        continue

# %%
nlp_aggregate_2018_positive
# Out:
# ['Best Revival of any game imo.',
#  'Its a fun Game ive enjoyed',
#  'this game is fun and endless',
#  'A great space exploration game',
#  'There now is men in the sky.',
#  'This game simply amazes me.',
#  'It really has come a long way',
#  'Better than at launch.',
#  'from the ashes a phoenix rises',
#  'This game is nuts',
#  'Still the best game on Steam.',
#  'best to play with friends',
#  'Great comeback! love this game',
#  "It's better than it was.",
#  'its pretty alright I guess',
#  'NICE keep going Hello games.',
#  'The game that keeps on giving!',
#  'getting better with updates',
#  'Most comeback game of the year',
#  'someof the views are stunning',
#  'Complete time sink great fun',
#  'Fun game.  Free updates, lots.',
#  'better than before I guess',
#  'Better than it was',
#  'Best when played with friends.',
#  'Great game many many updates.',
#  'Is better than it was before.',
#  'Got a lot better.',
#  'it got better i swear\n',
#  'it got better',
#  'A very fun game.',
#  'Amazing game, worth the price.',
#  'Its a lot better than it was.',
#  'Its a good game i love it',
#  'Game is fire after update',
#  'Pretty noice i guess.',
#  'this game is indeed good now.',
#  'Really dig this one',
#  'pretty good now aye',
#  'Really enjoyed this game :)',
#  'Played it a bit. Pretty gud',
#  'I still hate Sean Murray.',
#  'Good Game that i like',
#  'Really do love this game !!',
#  'I love this game a lot! <3',
#  'game revival of the century',
#  'it good but need battle royal',
#  'This is a very game',
#  'I LIKE THIS GAME',
#  'Fuckin love this game',
#  'Good game to relax \n',
#  'a very good game\n',
#  'its gooder now',
#  'Grindy but immersive',
#  'Are you happy now internet?',
#  'Its great now. Love it!',
#  'Loving the new NEXT update.',
#  'A Hero has Returned To Battle.',
#  'loving the new update',
#  'great game after last update',
#  'yep, i really enjoy the game..',
#  'Now thats more like it.',
#  'Fairly solid, decent game',
#  'The game i always dreamt of...',
#  'free DLC very nice',
#  'Its pretty good now yeah',
#  'Very Nice! I like.',
#  'Top 10 anime game comebacks',
#  'Top video game ressurection',
#  'best game to play forever',
#  'now ist a real game',
#  'The game is good now',
#  'getting to what was promised',
#  "i love this game it's amazing",
#  'Its pretty good now',
#  'Best game on steam',
#  'Improved greatly since launch.',
#  'Bad release. Constant updates.',
#  'game has come a long way',
#  'so much better now',
#  'veri gud new update yes',
#  'i think we need more vehicles',
#  'No longer makes you want death',
#  'its ok but needs more tbh \n',
#  'hey guys they fixed it',
#  'Devs keep working on this gem.',
#  'has gotten way better',
#  'i guess its nice',
#  "Love the new no man's sky",
#  'This game is fun and exciting!',
#  'This is a very funny game.',
#  "it's fun to explore space lol",
#  ' i wanna make it positive',
#  "The game's fun now.",
#  'I love this update',
#  'The game is amazing now.',
#  'They turned this game around\n',
#  'Top after the new update.',
#  'I mean This is a video game',
#  'So much better now!',
#  'Next makes it a whole new game',
#  'glad they added content',
#  'Great game to chill in.',
#  'Game is much better.',
#  'This game is a phenix.',
#  'NEXT has been pretty fun.',
#  'Basically a new game',
#  'Not in early access anymore',
#  'i like this game',
#  "It's pretty good now.",
#  '10x the game it used to be.',
#  'I love me some spaghetti <3',
#  'I love this game',
#  'I friggin love this game.',
#  'GOOD GAME IF IT UPDATES',
#  'Devs are doing a great job',
#  'I like it after latest updates',
#  'i luv me some sean murray',
#  'I love this game!',
#  'I like the word absurd.',
#  'Good after the NEXT update',
#  'yeah its better i guess v2',
#  'THE MADMEN DID IT, GOTY WORTHY',
#  'After NEXT totally new game.',
#  'i have never played this game',
#  'they made it wat we wanted. GG',
#  'Is now the game advertised.',
#  "It's a lot better now.",
#  'its aight now i guess',
#  'next made it good my fams',
#  'its better now i guess',
#  'The game is good now',
#  'Time to back The NEXT.',
#  'Give it a chance now.',
#  'good game much explore',
#  'Spent all my money on frigates',
#  'Game is better now',
#  'The game got a lot better.',
#  'They are getting there slowly.',
#  'Great game will buy it again !',
#  'Next makes it worth playing.',
#  'Buy during a steam sale.',
#  'Better than Star Citizen lmao',
#  "i mean i guess it's okay now",
#  'This game has come a long way',
#  'Game is very good now.',
#  'The game is good now',
#  'Its like a whole new game now',
#  "It's ok now I guess.",
#  'this game is dope',
#  'A lot better now',
#  'Ya know what, its pretty cool.',
#  'very glitchy but also very fun',
#  'EDIT: a lot better now :)',
#  'Okay, its a game now.']

# %%
nlp_2018_positive = generate_summary(nlp_aggregate_2018_positive)
nlp_2018_positive
# Out:
# ['now ist a real game',
#  'its better now i guess',
#  'Its pretty good now yeah',
#  'The game got a lot better.',
#  'Is now the game advertised.']

# %% [markdown]
# #### NLP 2018 negatives

# %%
mns_2018_negative = []

for i in range(len(mnsdata.loc[(mnsdata['Yearly'] == '2018') & (mnsdata['Recommended?'] == False)])):
    if 10 <= len(mnsdata.loc[(mnsdata['Yearly'] == '2018') & (mnsdata['Recommended?'] == False)]['Reviews'].values[i]) <= 30:
        mns_2018_negative.append(mnsdata.loc[(mnsdata['Yearly'] == '2018') & (mnsdata['Recommended?'] == False)]['Reviews'].values[i])

# %%
nlp_initial_2018_negative = [mns_2018_negative[(i*50):(i+1)*50] for i in range(math.ceil(len(mns_2018_negative)/50))]
nlp_aggregate_2018_negative = []

for i in range(len(nlp_initial_2018_negative)):
    try:
        nlp_aggregate_2018_negative += generate_summary(nlp_initial_2018_negative[i])
    except:
        continue

# %%
nlp_aggregate_2018_negative
# Out:
# ['Game runs like shit',
#  'LOWER THE FUCKING PRICE',
#  "Doesn't have any personality.",
#  'no deap sea anymore',
#  'A very boring game.',
#  'Stil not a high quality game.',
#  'I did not have fun.',
#  'got a refund',
#  "mindless autism. No Man's Buy",
#  'Gets boring VERY quickly',
#  'still runs like dog shit',
#  'Boring and confusing as hell.',
#  'runs like ass',
#  'And this game is still shit.',
#  'more like, no guy buy XD',
#  'um  game is legit broken',
#  'Enough has already been said.',
#  'Crap game. Want a refund.',
#  'worst game I ever bought.',
#  'The NEXT Update is awful.',
#  'Not at all what was expected.',
#  'low fps in game with decent pc',
#  'best game i ever play',
#  'Not worth the time or money.',
#  'It was a deception.']

# %%
nlp_2018_negative = generate_summary(nlp_aggregate_2018_negative)
nlp_2018_negative
# Out:
# ['Game runs like shit',
#  'um  game is legit broken',
#  'Enough has already been said.',
#  'Not worth the time or money.',
#  'more like, no guy buy XD']

# %% [markdown]
# #### NLP 2019 positives

# %%
mns_2019_positive = []

for i in range(len(mnsdata.loc[(mnsdata['Yearly'] == '2019') & (mnsdata['Recommended?'] == True)])):
    if 10 <= len(mnsdata.loc[(mnsdata['Yearly'] == '2019') & (mnsdata['Recommended?'] == True)]['Reviews'].values[i]) <= 30:
        mns_2019_positive.append(mnsdata.loc[(mnsdata['Yearly'] == '2019') & (mnsdata['Recommended?'] == True)]['Reviews'].values[i])

# %%
nlp_initial_2019_positive = [mns_2019_positive[(i*50):(i+1)*50] for i in range(math.ceil(len(mns_2019_positive)/50))]
nlp_aggregate_2019_positive = []

for i in range(len(nlp_initial_2019_positive)):
    try:
        nlp_aggregate_2019_positive += generate_summary(nlp_initial_2019_positive[i])
    except:
        continue
# Out:
# c:\users\ken\appdata\local\programs\python\python38-32\lib\site-packages\nltk\cluster\util.py:131: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (numpy.dot(u, v) / (sqrt(numpy.dot(u, u)) * sqrt(numpy.dot(v, v))))

# %%
nlp_aggregate_2019_positive
# Out:
# ['good game would recommend',
#  'ITS EN REALY GOED GAME',
#  'A very fun game in space.',
#  'glad they didnt give up',
#  'a very fun game!',
#  'Bad game turned v good game',
#  'Turned into a great game',
#  'its gotten alot better',
#  'BEST MUSIC SOFTWARE EDITING!',
#  'It is GREAT',
#  'This game has aged wonderfully',
#  'Got alot better with updates\n',
#  'Is a nice game',
#  'is big good, very recommend.',
#  'My new favorite game.',
#  'Needs more things to do',
#  'latest updates are amazing.',
#  'This is a really relaxing game',
#  'i mean its pre good now',
#  'It is nice to explore planets!',
#  "It's gotten much better.",
#  'this game is gangster',
#  'Ye its pretty good',
#  'eh. it got better',
#  'Just a fucking great game!',
#  'The best open world game',
#  'the game is better now',
#  'Eight. Take it, or leave it',
#  'Has turned into a nice game',
#  'Very fun game.',
#  'Only gets better with time',
#  'Meh to very GREAT GAME.',
#  'Started shit. Now its great',
#  'Best in VR yet',
#  'Most improved game in history?',
#  'pretty good now i guess.',
#  'Best game in history, ever.',
#  'Good mission oriented game',
#  'Good gaem.Like it very much.',
#  'its better than it used to be',
#  "It's gotten better I guess.",
#  'its a great game now!',
#  'explore build move. spacy game',
#  "It's getting better and better",
#  'good game never stop updating',
#  'man updates a great',
#  'Fun and pretty chill game',
#  'Great game loads of fun',
#  'They changed this game around',
#  'good fun open game',
#  'good game most of the time',
#  'update keeps on coming',
#  'GREAT GAME BUY IT',
#  'god tier game',
#  'BEST VR GAME YET!',
#  'good but game keeps crashing',
#  'great game and great community',
#  'get it on sale tho',
#  'great game just play it',
#  'epic flying, get on sale',
#  'I liked it from the begining',
#  'BEST GAME EVER AND VERY BIG !',
#  'awesome game in VR',
#  'great game to play and chill',
#  'love this game to bits',
#  'so yea this game incredible',
#  'good game at half price',
#  'This game improved a lot.',
#  'Good after Beyond update.',
#  'this game is pretty good',
#  'this game is pretty gamer',
#  'So god damn great game!',
#  'This game did a complete 180!',
#  'Love this game in VR',
#  'I CAN YEET AND BEAT MY MEAT!\n',
#  'Game is good, would recommend',
#  'This game is great in VR.',
#  'Yes is better game now\n',
#  'The best VR games todate.',
#  'Please Buy this for me!',
#  'It is a great game now.',
#  'Got there in the end :)',
#  'Best open world to date',
#  'It got better',
#  "i love no ethereum's sky",
#  'Great Game  Worth the money.',
#  'Big respect to Hello Games',
#  'Great Game, I love it',
#  'Pretty great game right now',
#  'I love this game.',
#  'Good game would recommend',
#  'great game so much fun to do.',
#  'It just gets better and better',
#  'It got better',
#  'Game is awesome and addictive!',
#  'Good game with friends',
#  'Bad game gets good. Very nice',
#  'es pretty good now',
#  'dis a pretty good game',
#  'Honestly a great game',
#  'Better than it was at release',
#  'good for the money',
#  'Game is pretty good now',
#  'A lot better now',
#  'nice game to kill some time',
#  'me likey the grind',
#  "It's better now I guess",
#  "It's a preetty good damn game!",
#  'Fun game, lots to discover.',
#  'game is pretty cool',
#  'The game is great now.',
#  'I really enjoy the game.',
#  'Good game can’t wait for VR',
#  'Better than it was at launch!',
#  'This game is cool.',
#  'Huge game for the money',
#  'Most wonderful game ever',
#  'Realy fun and good space',
#  'pretty cool game',
#  'Very very nice game',
#  'Game is pretty neat.',
#  'It is getting better!',
#  '4am, yep. i like this game',
#  'its preety good',
#  'Gets boring, but is ok game',
#  'Good open world game',
#  'got better, cool space game',
#  "Now it's a great game.",
#  'good for who love universe',
#  'nice game buy it tis good',
#  'is a great game',
#  'This game is awesome!',
#  "Well it's a game about space.",
#  'This game had his redemption.',
#  'I forgive you HELLO!',
#  'This game is now as promised.',
#  "It's pretty good now",
#  'Very foon gAME bOIs',
#  'Very nice as of Beyond',
#  "he's done it again.",
#  'yeah its pretty good now',
#  'the game s not shit anymore',
#  'incredible now in vr my god!',
#  "Game don't suck no more.",
#  "It's a decent game now.",
#  'The game has come a long way!',
#  'ok its good now. Review edited',
#  'Hey its good now.',
#  'vr in this game is great',
#  'UPDATE its a good game now fyi',
#  'This game is great now.',
#  'Is good. Better than it was.',
#  "it's much better now.",
#  'its not shit anymore',
#  'new update is p cool ig.']

# %%
nlp_2019_positive = generate_summary(nlp_aggregate_2019_positive)
nlp_2019_positive
# Out:
# ['The game is great now.',
#  'ITS EN REALY GOED GAME',
#  'Great Game  Worth the money.',
#  'Needs more things to do',
#  'Bad game gets good. Very nice']

# %% [markdown]
# #### NLP 2019 negatives

# %%
mns_2019_negative = []

for i in range(len(mnsdata.loc[(mnsdata['Yearly'] == '2019') & (mnsdata['Recommended?'] == False)])):
    if 10 <= len(mnsdata.loc[(mnsdata['Yearly'] == '2019') & (mnsdata['Recommended?'] == False)]['Reviews'].values[i]) <= 30:
        mns_2019_negative.append(mnsdata.loc[(mnsdata['Yearly'] == '2019') & (mnsdata['Recommended?'] == False)]['Reviews'].values[i])

# %%
nlp_initial_2019_negative = [mns_2019_negative[(i*50):(i+1)*50] for i in range(math.ceil(len(mns_2019_negative)/50))]
nlp_aggregate_2019_negative = []

for i in range(len(nlp_initial_2019_negative)):
    try:
        nlp_aggregate_2019_negative += generate_summary(nlp_initial_2019_negative[i])
    except:
        continue

# %%
nlp_aggregate_2019_negative.pop(12)
nlp_aggregate_2019_negative
# Out:
# ['worst game on steam.',
#  'shit game. dont buy it.',
#  'ok but controls are terrible',
#  'Waste of my hard earned cash.',
#  'Multiplayer is too screwed up.',
#  'it is SUPER boring holy hell',
#  'runs like ass',
#  'This game is extremely boring.',
#  'Runs so poorly I returned it',
#  'game is broken and sucks',
#  'gets boring after like an hour',
#  'This game is really boring.',
#  'how do i get a refud',
#  'Never loads , waste of money',
#  'fuck this game its still trash',
#  'Still a yikes from me chief.',
#  "Can't rebind keys",
#  'No mans promises.',
#  "Just don't buy it"]

# %%
nlp_2019_negative = generate_summary(nlp_aggregate_2019_negative)
nlp_2019_negative
# Out:
# ['gets boring after like an hour',
#  'This game is really boring.',
#  'Waste of my hard earned cash.',
#  'it is SUPER boring holy hell',
#  'worst game on steam.']

# %% [markdown]
# #### NLP 2020 positives

# %%
mns_2020_positive = []

for i in range(len(mnsdata.loc[(mnsdata['Yearly'] == '2020') & (mnsdata['Recommended?'] == True)])):
    if 10 <= len(mnsdata.loc[(mnsdata['Yearly'] == '2020') & (mnsdata['Recommended?'] == True)]['Reviews'].values[i]) <= 30:
        mns_2020_positive.append(mnsdata.loc[(mnsdata['Yearly'] == '2020') & (mnsdata['Recommended?'] == True)]['Reviews'].values[i])

# %%
nlp_initial_2020_positive = [mns_2020_positive[(i*50):(i+1)*50] for i in range(math.ceil(len(mns_2020_positive)/50))]
nlp_aggregate_2020_positive = []

for i in range(len(nlp_initial_2020_positive)):
    try:
        nlp_aggregate_2020_positive += generate_summary(nlp_initial_2020_positive[i])
    except:
        continue
# Out:
# c:\users\ken\appdata\local\programs\python\python38-32\lib\site-packages\nltk\cluster\util.py:131: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (numpy.dot(u, v) / (sqrt(numpy.dot(u, u)) * sqrt(numpy.dot(v, v))))
# c:\users\ken\appdata\local\programs\python\python38-32\lib\site-packages\nltk\cluster\util.py:131: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (numpy.dot(u, v) / (sqrt(numpy.dot(u, u)) * sqrt(numpy.dot(v, v))))
# c:\users\ken\appdata\local\programs\python\python38-32\lib\site-packages\nltk\cluster\util.py:131: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (numpy.dot(u, v) / (sqrt(numpy.dot(u, u)) * sqrt(numpy.dot(v, v))))

# %%
nlp_aggregate_2020_positive
# Out:
# ['Fun game to play with friends',
#  'great game to kill some time.',
#  'THE BEST EXPLORATION RPG EVER',
#  'such a wonderfull game',
#  'great game, well worth playing',
#  'its good i like very nice',
#  'I recommend this game.',
#  'Very good game, i cant stop',
#  'Good game lots of exploration.',
#  'I love Space games like this',
#  'really good open world game',
#  'Its a good Space-Adventure',
#  'dis geam great very fun friend',
#  'very good fun game',
#  'one of my most favorite game\n',
#  'Getting very nice this game.',
#  'Kinda like a pretty good game',
#  'Great game easy to play',
#  'Sweet game, great to chill',
#  'it is a great game\n',
#  'very lil time consuming game',
#  'Great game to play on VR',
#  'yes womans land is pretty good',
#  'A Good story line, endless fun',
#  'Cool game i guess',
#  'Good game to just relax with.',
#  'Easy to learn, beautiful game',
#  'awesome tons to do',
#  'used to be bad, is now good.',
#  'game good alien planets fly',
#  'This game is a suprise.',
#  'A game that keeps on giving.',
#  'it got better',
#  'it is a fun game',
#  'yes get it',
#  'Very fun good yes',
#  'Has aged like a Fine wine.',
#  "THey've come a very long way.",
#  'Yea its pretty fun.',
#  'good for keeping updates',
#  'One of the best games!',
#  'Cool game , keep it up dev',
#  'Nice Game ! i like it !',
#  'Pretty solid game',
#  'Biggest comeback of the year',
#  'Very nice game to relax',
#  'Great game, would recommend.',
#  'great game loads of fun',
#  'very fun game',
#  'best vr title hands down',
#  'Its getting there',
#  'More like no man sigh',
#  'Great game to past time.',
#  'Best Space Game out there',
#  'Best exploration game ever',
#  'It just keeps getting better.',
#  'Aged like a great whiskey.',
#  'Greatest comeback in gaming ..',
#  'BEST GROWING GAME EVER.',
#  'One of the best games.',
#  'It deserves a GOTY now',
#  'Great Game, worth the money.',
#  'Fun Game to play with Friends.',
#  'This game is really fun',
#  'this game needs more love',
#  'Great game to relax with.',
#  'Its pretty good now I guess',
#  'better than it was originally',
#  'Good game to waste time in',
#  'very good new update',
#  'i would recommend this game.',
#  'Great open world game \n',
#  'I want to like this game.',
#  'its good now they fixed it.',
#  'way better than on its release',
#  'One of the best VR games',
#  'Super relaxing game',
#  'very good game',
#  'I liked to play this game',
#  'Hello Games did good',
#  'One of the must-try games',
#  'Is fun space game.',
#  'I love everything about it.',
#  'Best space game out there',
#  'You can be a space pirate.',
#  'Game is very nice.',
#  'Rock steady game that I love!',
#  'Great way to kill some time.',
#  'nice game !! love it',
#  'Best redemption arc since Zuko',
#  'good game very fun',
#  'its pretty good yeah',
#  'This is my forever game.',
#  'Never gets old',
#  'an ever expanding game',
#  'Great game lots to see and do',
#  'Now the game is really good :)',
#  'pretty epic game, i wont lie',
#  'this is indeed an epic game',
#  'I can now recommend this game.',
#  'i need gas',
#  'Awesome game, came a long way.',
#  'Pretty fun space game',
#  'really fun and breath taking',
#  'This game is EpIc',
#  'This game is freakin epic',
#  'much better than 4 years ago\n',
#  'Great game a lot of fun',
#  'Interesting and epic visuals',
#  'Game is epic',
#  'its a pretty cool game ngl',
#  'good now like real good',
#  'Get money and ships nerd',
#  'Long term playing game',
#  'Hecking better than it was.',
#  'A big lonely space game',
#  'In Hello Games I trust !',
#  'Game improved Good enough!',
#  'Ye Ye IS GUD',
#  'Fun and addictive game.',
#  'its good for the sale price.',
#  'The new update is GREAT!',
#  'Space minecraft? must be good',
#  'love it. great game :D',
#  'This game is dope.',
#  'get it with friends maybe',
#  'game ruined my life\n',
#  'fun game... worth every penny',
#  'Best Exploration Game ever !',
#  'The true gaming comeback',
#  "They've come a long way",
#  'Yeah its pretty good now :)',
#  'It is more of a game now.',
#  'Its a great game',
#  'this game makes me go Y E S',
#  'Fun game to explore and grind',
#  'fun open world game',
#  "It's really become a good game",
#  'Really good fun game',
#  'universe is big yes ok thanks',
#  'Yep. This game is now based!',
#  'Origins really took it home',
#  'Very directed open world game',
#  'My go to relaxing game!',
#  'the ultimate end goodening.',
#  'So good and only gets better',
#  'This Game is pretty cool',
#  'I respect this game.',
#  'The only game you need',
#  'good fun and decent graphics',
#  'Best game in the world.',
#  'me and my mate love this game',
#  'Yeah very good game',
#  ' A great space-faring escape!',
#  'I like space shooty build game',
#  'Very fun space game yes',
#  'Getting better with age',
#  'My favorite game easily!',
#  'Great game overall I love it!',
#  'good game to play with others',
#  'a lot better after the updates',
#  'I like being an alien dwarf',
#  'Fun space buy what ever',
#  'It truly is a fantastic game',
#  'Good Game, so much to discover',
#  'DAN L GET THE GAME',
#  "This is a gamer's game",
#  'This game is great',
#  'Great game to chill with.',
#  'i love the game.',
#  'yeah its pretty great i guess',
#  'Very good game, like SPORE.',
#  'Cheapest game I ever bought',
#  'this is a strand type game',
#  'Fun space exploration game.',
#  'good times makin space homes\n',
#  'Great game with good emersion',
#  "It's a great exploration game.",
#  'alpha centauri we are coming',
#  'Very fun game',
#  'One of the best game to play',
#  'Cool game with Friends',
#  'pretty cool i guess',
#  'Good Game if you like space',
#  'they fixed the core game loop',
#  'No other game like it.',
#  'plenty to do if your new',
#  'Good game could be longer..',
#  'I lost the game :p',
#  'This game is awesome',
#  'very fun game to get lost in',
#  'great with all the updates',
#  'its a great game now',
#  'Very fun gameplay',
#  'awesome game to play',
#  'very good once you get into it',
#  'This game is incredible',
#  'great new update',
#  'Great game, must play\n',
#  'Pretty relaxing game.',
#  'A fun Exploration gmae',
#  'get this damn game  now',
#  'It is a great family game!',
#  "Yeah it's pretty good.",
#  'so much better then at launch',
#  "It's come a long way.",
#  'this game is great',
#  'its pretty good',
#  'ye it got better',
#  'get good at the game\n',
#  'great game lots and lots to do',
#  'one of my top 3 games ever',
#  'i love the open world',
#  'Get depressed and lost',
#  'really goed keeps you busy',
#  'Very fun open world game\n',
#  'Awesome game. Give it a try',
#  'The Game Is better now!',
#  'pretty good game now',
#  'The Ultimate Redemption Arc.',
#  'a very fun and good game',
#  'it has gotten so much better',
#  'great open world game\n',
#  'Its a great game.',
#  'I like playing this game.',
#  'This game is very fun Gamers',
#  'Best game I played in a WHILE.',
#  'Gek are pretty cute tho',
#  'This game is very fun.',
#  'Nice game !',
#  'The game is pretty good',
#  'GETTING BETTER ALL THE TIME',
#  'wtf u reading game reviews?',
#  "It's a great game",
#  'yeah its a game',
#  'game is a true game now',
#  'very nice but lag',
#  'Game does not have big homo',
#  'i really enjoy this games size',
#  'got dat exploration vibe',
#  'its a good explorer game',
#  'A game that keeps on giving',
#  "Eyy dat's pretty gooddd",
#  'it is a very big game\n',
#  'VERY FUN GAME',
#  'very good game minimal crashes',
#  'Awesome gameplay and graphics',
#  'variety og game play opyions',
#  'very epic thank you sean',
#  'it got better',
#  'Great game lots to do.',
#  'Was shit before, its great now',
#  'Its a great game\n',
#  'This Game Is AWESOME',
#  'Bruh I just really like space',
#  'BIG YES for gud space game.',
#  'Top tier. I love this game.',
#  'the ultimate redemption story.',
#  'it aged perfectly',
#  'you feel like a space suit',
#  'Very The Nice Game',
#  'planets had animal very scary',
#  'Good updates veri niz',
#  'Got so much better',
#  'Great game, highly recommend.',
#  'Nice game to help relaxing',
#  'cant be bored playing this',
#  'What a comeback, great game.',
#  'nice game just a lil buggy',
#  'Its a dope game.',
#  'This game is honestly great',
#  'get it on sale',
#  'A lot better than its original',
#  'This game is freaking insane!@',
#  'Love everything on it',
#  'A very fun and relaxing game',
#  'A fun very chill game!',
#  'need more bugs fix',
#  'they made it good',
#  'great game now',
#  'yes very fun game',
#  'game is now perfect',
#  'Pretty fun game tbh',
#  'The engoodening is real.',
#  'this game is good now, get it.',
#  'good game lah, perfect\n',
#  'its better now. i like space\n',
#  'Very good and fun game.',
#  'its amazing i recommend it\n',
#  'yeah its pretty alrightn ow',
#  'Good game fun space aventure',
#  'its is a great game',
#  'Great way to pass the time.',
#  'The game is good now',
#  'Fun Open world game!',
#  'the game is damn fun',
#  'I recommend this game!',
#  'gud game yes very reccomend',
#  'its a good game but not for me',
#  'great fun game',
#  "The game's great now.",
#  'Worth every digital penny.',
#  'game is VERY good now',
#  'I like the game, its fun',
#  'game is fire',
#  'A game to play for Eternity.',
#  'good open world game.',
#  'Good For VR! Flying is awesome',
#  'give it another chance please',
#  'Amazing game, superb devs.',
#  'Almost perfect sandbox game.',
#  '  Nice grindy game',
#  'its gotten way better',
#  'Great, Game tons of content',
#  'The story of a redemption',
#  'A really fun space game',
#  'Best way to self quarantine.',
#  'Best Game I Have Ever Played',
#  'Great chill game. Love it',
#  'Almost as good as shenmue 4',
#  'Game has improved since launch',
#  'funny alien make me go :p',
#  'Best game for vr out there',
#  'ya its pretty good',
#  'Where is my son',
#  'many much explore, good game',
#  'Get it on sale.',
#  'Fantastic and getting better',
#  'Best space game ever done.',
#  'Fun game, and great story',
#  'Great game! Very in depth!',
#  'Best game since awhile !',
#  'a lot to do. Great game!',
#  'Best Exploration game ever.',
#  "yeh it's pretty good",
#  'Good game now made even better',
#  "It's gotten so much better!",
#  'Gud Game real fun',
#  'Fun game, good time sink',
#  'Not bheed, good soize',
#  'gud if you like space grind',
#  'It has come leaps and bounds',
#  'This game is rather neat',
#  "It's easy to play stoned",
#  'Fun Game, much exploration',
#  'very good game fun to play',
#  'Best gaming redemption story.',
#  'Great space sandbox game!',
#  'It is very nice smile\n',
#  'cringe maybe but cringe so',
#  'dope game for teens',
#  'Great open world game',
#  'Good game buy when on sale',
#  'Its a great game now.',
#  'it got better',
#  'I love the game in every way.',
#  'The game is great!',
#  'Great game, ultimate sandbox',
#  'It is an amazing Experience.',
#  'Avery would love this game :)',
#  'everything, lol game is epic',
#  ' Very Epic, Ngl',
#  'good game, a lot of open world',
#  'Best game I ever play',
#  'Very fun and addictive game!',
#  'This game is pretty neat now.',
#  'Its the best open evryting :D',
#  'yo this game is neat',
#  'VERY FUN AND INTERESTING GAME',
#  'gooder then was launch',
#  'Great game, a lot of depth.',
#  'this game was made for me',
#  'Gave me an existential crisis.',
#  'I love this game',
#  'Zero to hero in just 4 years',
#  'an awsome space game',
#  "hey it's pretty good",
#  'they done good',
#  'Worth it, even at full price.',
#  'they made it good',
#  'This game is really fun',
#  'its a fun calming experience',
#  'Very nice game now',
#  'good game\nno mans lie no more',
#  'very nice, i like',
#  'Is now good after updates',
#  'its been improved a lot',
#  'The improved alot, try it out.',
#  'Best anime redemption arc',
#  'its pretty dope now',
#  'Great game! A must play',
#  'This is a good game. The end.',
#  'I enjoyed it for a bit.',
#  'All around great game',
#  'This is an amazing game',
#  'its a great game to explore',
#  'Plot twist of the century.',
#  'Fantastic game to relax with.\n',
#  'Hands down my favorite game.',
#  'best game ever hands down',
#  "Game's pretty good nowadays",
#  'Gayme gets me hoird',
#  'nice game bro',
#  'Its my favorite game',
#  'Game is good now.',
#  'GET IT. YOU WONT REGRET IT.',
#  'this game is wonderful :)',
#  'it space game you go fly',
#  'Thank you Sean very cool',
#  'very fun game',
#  'eh, pretty good now',
#  'Now this became really good!',
#  "No longer a no man's lie",
#  'well, its not bad anymore',
#  "No man's lie was a lie.",
#  'Game is pretty good now 👍',
#  'better than it was',
#  'Is pretty good now',
#  'Game = Better now',
#  'Game is good now. Well done.',
#  'made the game fun',
#  'Lots of contents through years',
#  'They fixed it and now its fun',
#  'Game is gud now.',
#  'what a great redemption arc.',
#  "Yeah, it's pretty good now.",
#  'THE GAME IS GOOD NOW',
#  'yeah its pretty great now',
#  'Has come a long way.',
#  "It's pretty good now.",
#  'game good very now yes',
#  'A strand type game.',
#  'its gotten pretty good',
#  'Got a lot better',
#  'Game is gud now. Thanks Sean',
#  'much better now, good game',
#  'They were the good guys.',
#  'They done good.',
#  'yo this game fun as hell',
#  'So much better now! :)']

# %%
nlp_2020_positive = generate_summary(nlp_aggregate_2020_positive)
nlp_2020_positive
# Out:
# ['Great game lots to see and do',
#  'game is a true game now',
#  'So good and only gets better',
#  'very fun game to get lost in',
#  'This game is very fun Gamers']

# %% [markdown]
# #### NLP 2020 negatives

# %%
mns_2020_negative = []

for i in range(len(mnsdata.loc[(mnsdata['Yearly'] == '2020') & (mnsdata['Recommended?'] == False)])):
    if 10 <= len(mnsdata.loc[(mnsdata['Yearly'] == '2020') & (mnsdata['Recommended?'] == False)]['Reviews'].values[i]) <= 30:
        mns_2020_negative.append(mnsdata.loc[(mnsdata['Yearly'] == '2020') & (mnsdata['Recommended?'] == False)]['Reviews'].values[i])

# %%
nlp_initial_2020_negative = [mns_2020_negative[(i*50):(i+1)*50] for i in range(math.ceil(len(mns_2020_negative)/50))]
nlp_aggregate_2020_negative = []

for i in range(len(nlp_initial_2020_negative)):
    try:
        nlp_aggregate_2020_negative += generate_summary(nlp_initial_2020_negative[i])
    except:
        continue

# %%
nlp_aggregate_2020_negative
# Out:
# ['gets boring after 2 hours',
#  'It is a boring game.',
#  'game nhu cai lon',
#  "CAN'T LOAD INTO FRIENDS GAME",
#  'complete and utter shit',
#  'Only got shit freighters.',
#  'Quite frankly, the game sucks',
#  'I hate this fucking tutorial.',
#  'n ever mind famix was right',
#  "Can't even load the game.",
#  'no gameplay on this game',
#  'Just not my style of game.',
#  'I want a freaking refund steam',
#  'This is a game inside of a bug',
#  'new crap still boring.',
#  'i just cant start the game.',
#  'Runs like shit on AMD',
#  'it blue screens all time',
#  'Game randomly crashes',
#  'Go play Astroneer',
#  "I don't care anymore",
#  'Better than it was',
#  'Still not a video game yet.',
#  "Can't fly into the sun, 0/10",
#  'it is still boring']

# %%
nlp_2020_negative = generate_summary(nlp_aggregate_2020_negative)
nlp_2020_negative
# Out:
# ['i just cant start the game.',
#  "CAN'T LOAD INTO FRIENDS GAME",
#  'n ever mind famix was right',
#  'no gameplay on this game',
#  'Runs like shit on AMD']

# %% [markdown]
# #### NLP 2021 positives

# %%
mns_2021_positive = []

for i in range(len(mnsdata.loc[(mnsdata['Yearly'] == '2021') & (mnsdata['Recommended?'] == True)])):
    if 10 <= len(mnsdata.loc[(mnsdata['Yearly'] == '2021') & (mnsdata['Recommended?'] == True)]['Reviews'].values[i]) <= 30:
        mns_2021_positive.append(mnsdata.loc[(mnsdata['Yearly'] == '2021') & (mnsdata['Recommended?'] == True)]['Reviews'].values[i])

# %%
nlp_initial_2021_positive = [mns_2021_positive[(i*50):(i+1)*50] for i in range(math.ceil(len(mns_2021_positive)/50))]
nlp_aggregate_2021_positive = []

for i in range(len(nlp_initial_2021_positive)):
    try:
        nlp_aggregate_2021_positive += generate_summary(nlp_initial_2021_positive[i])
    except:
        continue

# %%
nlp_aggregate_2021_positive
# Out:
# ['Great game lots of new content',
#  'Love the big open universe',
#  'awesome game. very fun',
#  'It never ends and never fails.',
#  'just keeps getting better',
#  'this game is ruining my life',
#  'the game is lit',
#  'gucci mane lil mosey is white\n',
#  'gud game. fun gamer moment.',
#  'yeah its pretty good\n',
#  'Love it, get it nerd.',
#  'it good game if like space\n',
#  'Space Exploration gud & fun',
#  "There's a lot here to enjoy!",
#  'A lot of fun especially in VR.',
#  'its space and there are frogs',
#  'Love my pet T-Rexy thing!',
#  'So fun! Love the grind <3',
#  'THE GAME IS FIXED AND WHOLE!',
#  'its a great game',
#  'this game is better on pc.',
#  'Good game. Would recomend',
#  'this game is endless.',
#  'The best space game for me.',
#  'Space game is fun',
#  'crashing but i love the game',
#  'space or something',
#  'the game good rely good',
#  'Noice Game ( SagAmire ?)',
#  'IT DO BE GREAT GAM NGL',
#  "It's a really nice game.",
#  'Great game with new Content .\n',
#  'Pretty fun game',
#  'It is so great and beautiful',
#  'THIS GAME is pretty cool',
#  'Great game, especially in VR!',
#  'yes more updates pls ty',
#  'Top 10 Anime Redemption Arcs',
#  'fun game i liek game',
#  'mmm space moment',
#  'very good\ndo recommend yes buy',
#  'It was better than promised',
#  'Such a great improvement arc.',
#  'i like this game',
#  'the vast story line\n',
#  'Endless hours of a good game',
#  'game is good, could be longer.',
#  'game is fire now',
#  'Just a great game overall',
#  'game is very addicting',
#  'I am really into this game',
#  'i love that game',
#  'I LOVE THE GAME',
#  'i like this game.',
#  'One of best games =)',
#  "it's better space valheim",
#  'Hehe funny space game.',
#  'obsessed, would def recommend',
#  'space feels good',
#  'Pretty cool. Very engaging.',
#  'space game very good very fun',
#  'Very Relaxing and fun game.',
#  'I like ver much, enjoy I do!',
#  'I like making the big money',
#  'space game good now',
#  'good game, lots of content',
#  'Pretty fun game man.',
#  'gud game 4 nerds',
#  'fun space game',
#  'cool game , relaxing',
#  'good now please buy',
#  'this game is fucking awesome',
#  'best game on steam',
#  'Best space game out imo',
#  'best space exploration game',
#  'Very cool game, get it',
#  'Too good too be true',
#  'Great VR and Desktop game',
#  'ALL YOUR BASE ARE BELONG TO US',
#  'My favorite game of all time.',
#  'This game is incredible',
#  'Incredible open world game',
#  'Just keeps getting better.',
#  'this is the game a dreamed',
#  'Just keeps getting better!',
#  'the most fun boring game ever',
#  'Get lost on a space voyage.',
#  'It just keeps getting better',
#  'Great game in VR',
#  'New updates are great\n',
#  'yes get it now',
#  'its pretty fun i enjoy it\n',
#  "Yea it's pretty good",
#  'I think this is my dream game!',
#  'theres a man in the sky',
#  'game is very good, much fun',
#  'game of the year!',
#  'hell yea one of my fav games',
#  'hehe planet go gravity\n',
#  'Shrek is a good movie.',
#  'i turned into a great game',
#  'it good game. very fun yes\n',
#  'REALY GOOD GAME SUPER FUN',
#  'great game even in VR',
#  'give me your points\n',
#  'The Elite Dangerous of Roblox',
#  'This is a game for explorers.',
#  'Relaxing space game',
#  'really good an in depth',
#  'Worth the hole in my pocket',
#  'Get it on sale',
#  'Best game on the market',
#  'Really good and fun game',
#  'Skyrim but on a space level',
#  'Feels like a $60 game now',
#  'We forgive you Hello Games.',
#  'one of the best VR games ever',
#  'Wall street but in space',
#  'very very fun and pog',
#  ' Its pretty good now',
#  'very good game',
#  'veri gud, do liek gam3',
#  'A very chill game',
#  'This is the BEST future game',
#  'Greatest redemption arch ever.',
#  'yeah is good i recommend',
#  'worth your money well spent',
#  'Awesome game to chill out!',
#  'Mans Got Powers',
#  'fun game space',
#  'beast space game i ever   play',
#  'Spore space stage done right.',
#  'Good but even better in VR',
#  'issa veri gud gaem',
#  'VR mode 4 the win',
#  'A much better game now',
#  'changed alot got alot better',
#  'The game that keeps on giving.',
#  'this game is awesome now',
#  'it be good now',
#  'Game is better now.',
#  '>devs made it worthy again',
#  'Chris said the game was great,',
#  'eh updates are nice but buggy',
#  'the game is fun now']

# %%
nlp_2021_positive = generate_summary(nlp_aggregate_2021_positive)
nlp_2021_positive
# Out:
# ['Endless hours of a good game',
#  'yeah is good i recommend',
#  'the most fun boring game ever',
#  'this game is better on pc.',
#  'crashing but i love the game']

# %% [markdown]
# #### NLP 2021 negatives

# %%
mns_2021_negative = []

for i in range(len(mnsdata.loc[(mnsdata['Yearly'] == '2021') & (mnsdata['Recommended?'] == False)])):
    if 10 <= len(mnsdata.loc[(mnsdata['Yearly'] == '2021') & (mnsdata['Recommended?'] == False)]['Reviews'].values[i]) <= 30:
        mns_2021_negative.append(mnsdata.loc[(mnsdata['Yearly'] == '2021') & (mnsdata['Recommended?'] == False)]['Reviews'].values[i])

# %%
nlp_initial_2021_negative = [mns_2021_negative[(i*50):(i+1)*50] for i in range(math.ceil(len(mns_2021_negative)/50))]
nlp_aggregate_2021_negative = []

for i in range(len(nlp_initial_2021_negative)):
    try:
        nlp_aggregate_2021_negative += generate_summary(nlp_initial_2021_negative[i])
    except:
        continue

# %%
nlp_aggregate_2021_negative
# Out:
# ['dont buy this game',
#  "No man's play this game.",
#  'Cant reach stars, bad game',
#  "It's a refund sim",
#  'This is NOT a COOP game!',
#  'Sean your are a lying bitсh!',
#  'still dont like the game sorry',
#  'The monitor cannot be rotated.',
#  "Game doesn't load anymore",
#  "CAN'T EVEN RUN THE GAME."]

# %%
nlp_2021_negative = generate_summary(nlp_aggregate_2021_negative)
nlp_2021_negative
# Out:
# ['Sean your are a lying bitсh!',
#  'The monitor cannot be rotated.',
#  "CAN'T EVEN RUN THE GAME.",
#  "Game doesn't load anymore",
#  "No man's play this game."]

# %% [markdown]
# The error handling exists because there are cases where even a batch (50) of reviews would not have anything in common, therefore it returns an error. Rather stepping in to see if it could be salvaged, it is more optimal to be skipped instead.
#
# Even after that, there may be a few reviews that do not fit the right category or they are low-effort trolling reviews. The reviews are then individually removed, and the batches of reviews are then recompiled.
#
# That should do it! Now it is time for a new dataframe built on our refined reviews.

# %% [markdown]
# ### NLP dataframe

# %%
year_data = 2*[i for i in range(2016, 2022)]
nlpdata = pd.DataFrame(year_data, columns = ['Year'])
nlpdata
# Out:
#     Year
# 0   2016
# 1   2017
# 2   2018
# 3   2019
# 4   2020
# 5   2021
# 6   2016
# 7   2017
# 8   2018
# 9   2019
# 10  2020
# 11  2021

# %%
nlp_2016_positive_string = '. '.join([i for i in nlp_2016_positive])
nlp_2017_positive_string = '. '.join([i for i in nlp_2017_positive])
nlp_2018_positive_string = '. '.join([i for i in nlp_2018_positive])
nlp_2019_positive_string = '. '.join([i for i in nlp_2019_positive])
nlp_2020_positive_string = '. '.join([i for i in nlp_2020_positive])
nlp_2021_positive_string = '. '.join([i for i in nlp_2021_positive])

# %%
nlp_2016_negative_string = '. '.join([i for i in nlp_2016_negative])
nlp_2017_negative_string = '. '.join([i for i in nlp_2017_negative])
nlp_2018_negative_string = '. '.join([i for i in nlp_2018_negative])
nlp_2019_negative_string = '. '.join([i for i in nlp_2019_negative])
nlp_2020_negative_string = '. '.join([i for i in nlp_2020_negative])
nlp_2021_negative_string = '. '.join([i for i in nlp_2021_negative])

# %%
nlp_positives = [nlp_2016_positive_string, nlp_2017_positive_string, nlp_2018_positive_string, nlp_2019_positive_string, nlp_2020_positive_string, nlp_2021_positive_string]
nlp_negatives = [nlp_2016_negative_string, nlp_2017_negative_string, nlp_2018_negative_string, nlp_2019_negative_string, nlp_2020_negative_string, nlp_2021_negative_string]

# %%
positive_review_count = [len(mnsdata.loc[(mnsdata['Yearly'] == f'{i}') & (mnsdata['Recommended?'] == True)]['Reviews']) for i in range(2016, 2022)]
negative_review_count = [len(mnsdata.loc[(mnsdata['Yearly'] == f'{i}') & (mnsdata['Recommended?'] == True)]['Reviews']) for i in range(2016, 2022)]

# %%
nlpdata['Reviews'] = nlp_positives+nlp_negatives
nlpdata['Category'] = ['Positive']*6 + ['Negative']*6
nlpdata['Count'] = positive_review_count + negative_review_count
nlpdata
# Out:
#     Year                                            Reviews  Category  Count
# 0   2016  best game ive played in years.. i love the gam...  Positive  14545
# 1   2017  me dude its great now. Better than a year ago....  Positive   5641
# 2   2018  now ist a real game. its better now i guess. I...  Positive  14430
# 3   2019  The game is great now.. ITS EN REALY GOED GAME...  Positive  12779
# 4   2020  Great game lots to see and do. game is a true ...  Positive  28361
# 5   2021  Endless hours of a good game. yeah is good i r...  Positive   8162
# 6   2016  I DEMAND A REFUND N THIS GAME.. WHY  WONT IT L...  Negative  14545
# 7   2017  how do i get a refund. Wish i could get a refu...  Negative   5641
# 8   2018  Game runs like shit. um  game is legit broken....  Negative  14430
# 9   2019  gets boring after like an hour. This game is r...  Negative  12779
# 10  2020  i just cant start the game.. CAN'T LOAD INTO F...  Negative  28361
# 11  2021  Sean your are a lying bitсh!. The monitor cann...  Negative   8162

# %% [markdown]
# The dataframe is structured this way because of how the storyboard will be set up.

# %% [markdown]
# ### Datasheet export

# %%
nlpdata.to_csv('nomansskynlp.csv')

# %% [markdown]
# ## Credits:
# Immense gratitude to <b>Forerunners</b> for their code.
#
# Links to their accounts can be found here: <br>
# https://www.youtube.com/channel/UCOv8xYSnv27f-z5SiKLYajQ <br>
# https://twitter.com/Forerunners_PS
